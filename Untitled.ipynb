# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# %%
# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# %%
# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# %%
# Combine the data into a single dataset
mouse_metadata['Sex'].value_counts()
# Out:
# Male      125
# Female    124
# Name: Sex, dtype: int64

# %%
study_results
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0        b128          0           45.000000                 0
# 1        f932          0           45.000000                 0
# 2        g107          0           45.000000                 0
# 3        a457          0           45.000000                 0
# 4        c819          0           45.000000                 0
# ...       ...        ...                 ...               ...
# 1888     r944         45           41.581521                 2
# 1889     u364         45           31.023923                 3
# 1890     p438         45           61.433892                 1
# 1891     x773         45           58.634971                 4
# 1892     b879         45           72.555239                 2
#
# [1893 rows x 4 columns]

# %%
# Combine the data into a single dataset
# Display the data table for preview
combined_results = pd.merge(study_results, mouse_metadata, on='Mouse ID', how='left')
combined_results
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        f932          0           45.000000                 0     Ketapril
# 2        g107          0           45.000000                 0     Ketapril
# 3        a457          0           45.000000                 0     Ketapril
# 4        c819          0           45.000000                 0     Ketapril
# ...       ...        ...                 ...               ...          ...
# 1888     r944         45           41.581521                 2    Capomulin
# 1889     u364         45           31.023923                 3    Capomulin
# 1890     p438         45           61.433892                 1     Ceftamin
# 1891     x773         45           58.634971                 4      Placebo
# 1892     b879         45           72.555239                 2     Stelasyn
#
#          Sex  Age_months  Weight (g)
# 0     Female           9          22
# 1       Male          15          29
# 2     Female           2          29
# 3     Female          11          30
# 4       Male          21          25
# ...      ...         ...         ...
# 1888    Male          12          25
# 1889    Male          18          17
# 1890  Female          11          26
# 1891  Female          21          30
# 1892  Female           4          26
#
# [1893 rows x 8 columns]

# %%
 # Checking the number of mice.
len(combined_results['Mouse ID'].unique())
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
combined_results = combined_results.drop_duplicates()
combined_results
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        f932          0           45.000000                 0     Ketapril
# 2        g107          0           45.000000                 0     Ketapril
# 3        a457          0           45.000000                 0     Ketapril
# 4        c819          0           45.000000                 0     Ketapril
# ...       ...        ...                 ...               ...          ...
# 1888     r944         45           41.581521                 2    Capomulin
# 1889     u364         45           31.023923                 3    Capomulin
# 1890     p438         45           61.433892                 1     Ceftamin
# 1891     x773         45           58.634971                 4      Placebo
# 1892     b879         45           72.555239                 2     Stelasyn
#
#          Sex  Age_months  Weight (g)
# 0     Female           9          22
# 1       Male          15          29
# 2     Female           2          29
# 3     Female          11          30
# 4       Male          21          25
# ...      ...         ...         ...
# 1888    Male          12          25
# 1889    Male          18          17
# 1890  Female          11          26
# 1891  Female          21          30
# 1892  Female           4          26
#
# [1892 rows x 8 columns]

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
combined_results = combined_results.drop_duplicates(subset=['Mouse ID','Timepoint'], keep='first' )
combined_results
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        f932          0           45.000000                 0     Ketapril
# 2        g107          0           45.000000                 0     Ketapril
# 3        a457          0           45.000000                 0     Ketapril
# 4        c819          0           45.000000                 0     Ketapril
# ...       ...        ...                 ...               ...          ...
# 1888     r944         45           41.581521                 2    Capomulin
# 1889     u364         45           31.023923                 3    Capomulin
# 1890     p438         45           61.433892                 1     Ceftamin
# 1891     x773         45           58.634971                 4      Placebo
# 1892     b879         45           72.555239                 2     Stelasyn
#
#          Sex  Age_months  Weight (g)
# 0     Female           9          22
# 1       Male          15          29
# 2     Female           2          29
# 3     Female          11          30
# 4       Male          21          25
# ...      ...         ...         ...
# 1888    Male          12          25
# 1889    Male          18          17
# 1890  Female          11          26
# 1891  Female          21          30
# 1892  Female           4          26
#
# [1888 rows x 8 columns]

# %%
# Optional: Get all the data for the duplicate mouse ID.
# Out:
# 249

# %%
# Checking the number of mice in the clean DataFrame.

# %%
reg_df = (combined_results['Drug Regimen'].value_counts()).to_frame()
reg_df = reg_df.rename(columns={'Drug Regimen': 'Subject Count'})
reg_df
# Out:
#            Subject Count
# Capomulin            230
# Ramicane             228
# Ketapril             188
# Naftisol             186
# Zoniferol            182
# Placebo              181
# Stelasyn             181
# Ceftamin             178
# Infubinol            178
# Propriva             156

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

capomulin = combined_results.loc[combined_results['Drug Regimen']=='Capomulin',:]
capomulin.describe()
# Out:
#         Timepoint  Tumor Volume (mm3)  Metastatic Sites  Age_months  \
# count  230.000000          230.000000        230.000000  230.000000
# mean    21.565217           40.675741          0.713043   13.456522
# std     14.384994            4.994774          0.848993    7.721423
# min      0.000000           23.343598          0.000000    1.000000
# 25%     10.000000           37.685933          0.000000    7.000000
# 50%     20.000000           41.557809          0.000000   16.500000
# 75%     35.000000           45.000000          1.000000   20.000000
# max     45.000000           48.158209          3.000000   24.000000
#
#        Weight (g)
# count  230.000000
# mean    19.965217
# std      2.732404
# min     15.000000
# 25%     17.000000
# 50%     20.500000
# 75%     22.000000
# max     25.000000

# %%
# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.

# %%
reg2_df = combined_results.groupby(['Drug Regimen'])

# %%
(reg2_df.get_group('Capomulin')).describe()
# Out:
#         Timepoint  Tumor Volume (mm3)  Metastatic Sites  Age_months  \
# count  230.000000          230.000000        230.000000  230.000000
# mean    21.565217           40.675741          0.713043   13.456522
# std     14.384994            4.994774          0.848993    7.721423
# min      0.000000           23.343598          0.000000    1.000000
# 25%     10.000000           37.685933          0.000000    7.000000
# 50%     20.000000           41.557809          0.000000   16.500000
# 75%     35.000000           45.000000          1.000000   20.000000
# max     45.000000           48.158209          3.000000   24.000000
#
#        Weight (g)
# count  230.000000
# mean    19.965217
# std      2.732404
# min     15.000000
# 25%     17.000000
# 50%     20.500000
# 75%     22.000000
# max     25.000000

# %%
tumor_vol_m = reg2_df['Tumor Volume (mm3)'].mean()
# Out:
# Drug Regimen
# Capomulin    40.675741
# Ceftamin     52.591172
# Infubinol    52.884795
# Ketapril     55.235638
# Naftisol     54.331565
# Placebo      54.033581
# Propriva     52.393463
# Ramicane     40.216745
# Stelasyn     54.233149
# Zoniferol    53.236507
# Name: Tumor Volume (mm3), dtype: float64

# %%
tumor_vol_std = reg2_df['Tumor Volume (mm3)'].std()
tumor_vol_std
# Out:
# Drug Regimen
# Capomulin    4.994774
# Ceftamin     6.268188
# Infubinol    6.567243
# Ketapril     8.279709
# Naftisol     8.134708
# Placebo      7.821003
# Propriva     6.568014
# Ramicane     4.846308
# Stelasyn     7.710419
# Zoniferol    6.966589
# Name: Tumor Volume (mm3), dtype: float64

# %%
tumor_vol_med = reg2_df['Tumor Volume (mm3)'].median()
tumor_vol_med
# Out:
# Drug Regimen
# Capomulin    41.557809
# Ceftamin     51.776157
# Infubinol    51.820584
# Ketapril     53.698743
# Naftisol     52.509285
# Placebo      52.288934
# Propriva     50.909965
# Ramicane     40.673236
# Stelasyn     52.431737
# Zoniferol    51.818479
# Name: Tumor Volume (mm3), dtype: float64

# %%
tumor_vol_stats = reg2_df['Tumor Volume (mm3)'].agg(['mean','median','std','var','sem'])
tumor_vol_stats
# Out:
#                    mean     median       std        var       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  4.994774  24.947764  0.329346
# Ceftamin      52.591172  51.776157  6.268188  39.290177  0.469821
# Infubinol     52.884795  51.820584  6.567243  43.128684  0.492236
# Ketapril      55.235638  53.698743  8.279709  68.553577  0.603860
# Naftisol      54.331565  52.509285  8.134708  66.173479  0.596466
# Placebo       54.033581  52.288934  7.821003  61.168083  0.581331
# Propriva      52.393463  50.909965  6.568014  43.138803  0.525862
# Ramicane      40.216745  40.673236  4.846308  23.486704  0.320955
# Stelasyn      54.233149  52.431737  7.710419  59.450562  0.573111
# Zoniferol     53.236507  51.818479  6.966589  48.533355  0.516398

# %%
# mind blown

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line

# %%
 # Generate a bar plot showing the total number of unique mice tested on each drug regimen using pandas.
drug_regimens = list(reg_df.index.values)
mouse_count = reg_df['Subject Count']
pd.plot.bar(x=drug_regimens, y=mouse_count)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-79-f0e946c1935d> in <module>
#       2 drug_regimens = list(reg_df.index.values)
#       3 mouse_count = reg_df['Subject Count']
# ----> 4 pd.plot.bar(x=drug_regimens, y=mouse_count)
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     261             return _SparseArray
#     262
# --> 263         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     264
#     265
#
# AttributeError: module 'pandas' has no attribute 'plot'

# %%
# Generate a bar plot showing the total number of unique mice tested on each drug regimen using pyplot.

drug_regimens = list(reg_df.index.values)
x_axis = np.arange(len(reg_df))
subject_count = reg_df['Subject Count']
plt.bar(x_axis, subject_count, align='center')
plt.xticks(x_axis, drug_regimens, rotation=90)
plt.xlabel('Drug Regimen')
plt.ylabel('Number of Mice Tested')
plt.title('Number of Mice Tested per Drug Regimen')
plt.show()

# %%
# Group mice by sex 
sex_df = mouse_metadata.groupby(['Sex'])
male_subjects = len(sex_df.get_group('Male'))
female_subjects = len(sex_df.get_group('Female'))

sex_df2 = pd.DataFrame({'sex_count':[male_subjects, female_subjects]},
                      index=['Male', 'Female'])

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
sex_df2.plot.pie(y='sex_count')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
labels=['Male','Female']
sizes =[male_subjects, female_subjects]
colors=['skyblue','pink']
plt.pie(sizes, labels=labels, colors=colors, startangle=90)
plt.title('Male vs Female Mice in Drug Regimens')
plt.show()

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

by_mouse_df = combined_results.sort_values(['Mouse ID', 'Timepoint'])
by_mouse_df
final_tvolume_df = by_mouse_df.drop_duplicates(subset=['Mouse ID'], keep='last')
final_tvolume_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 1804     a203         45           67.973419                 2    Infubinol
# 1786     a251         45           65.525743                 1    Infubinol
# 1783     a262         45           70.717621                 4      Placebo
# 1856     a275         45           62.999356                 3     Ceftamin
# 1401     a366         30           63.440686                 1     Stelasyn
# ...       ...        ...                 ...               ...          ...
# 499      z435         10           48.710661                 0     Propriva
# 1799     z578         45           30.638696                 0     Ramicane
# 1784     z581         45           62.754451                 3    Infubinol
# 1887     z795         45           65.741070                 3     Naftisol
# 1869     z969         45           73.867845                 4     Naftisol
#
#          Sex  Age_months  Weight (g)
# 1804  Female          20          23
# 1786  Female          21          25
# 1783  Female          17          29
# 1856  Female          20          28
# 1401  Female          16          29
# ...      ...         ...         ...
# 499   Female          12          26
# 1799    Male          11          16
# 1784  Female          24          25
# 1887  Female          13          29
# 1869    Male           9          30
#
# [249 rows x 8 columns]

# %%
# Start by getting the last (greatest) timepoint for each mouse

# %%
# Merge this group df with the original dataframe to get the tumor volume at the last timepoint

# %%
# Put treatments into a list for for loop (and later for plot labels)


# Create empty list to fill with tumor vol data (for plotting)


# Calculate the IQR and quantitatively determine if there are any potential outliers. 

    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    
    
    # add subset 
    
    
    # Determine outliers using upper and lower bounds

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

# ---> is this 4 different plots?

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
